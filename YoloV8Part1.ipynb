# %%
import os, shutil
from ultralytics import YOLO
import cv2

# %%
MODEL_PATH = "yolov8n.pt"
INPUT_FOLDER = "input_images"
OUTPUT_FOLDER = "output"

def detect_object():
    model = YOLO(MODEL_PATH)

    os.makedirs(OUTPUT_FOLDER)
    if os.path.exists(OUTPUT_FOLDER):
        shutil.rmtree(OUTPUT_FOLDER)
        os.makedirs(OUTPUT_FOLDER)

    for image_name in os.listdir(INPUT_FOLDER):
        input_path = os.path.join(INPUT_FOLDER, image_name)
        output_path = os.path.join(OUTPUT_FOLDER, image_name)

        if not input_path.lower().endswith(('.png', '.jpg', '.jepg')):
            continue

        results = model.predict(input_path, conf=0.5, save = False)

        for result in results:
            annotated_image = result.plot(result)
            cv2.imwrite(output_path, annotated_image)
            print ("Hasil deteksi disimpan ke: {image_name}")

# %%
if __name__ == "__main__":
    detect_object()
# Out:
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\bunny.jpg: 448x640 1 bird, 191.4ms
# Speed: 38.6ms preprocess, 191.4ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\dog.jpg: 640x480 1 dog, 160.1ms
# Speed: 4.6ms preprocess, 160.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\elephant.jpg: 640x576 1 elephant, 175.0ms
# Speed: 5.0ms preprocess, 175.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\film.png: 640x576 (no detections), 127.4ms
# Speed: 5.7ms preprocess, 127.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\fox.jpg: 640x448 1 dog, 126.1ms
# Speed: 4.0ms preprocess, 126.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\lion.jpg: 640x512 (no detections), 133.0ms
# Speed: 3.5ms preprocess, 133.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\meerkat.jpg: 640x640 (no detections), 176.2ms
# Speed: 4.8ms preprocess, 176.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda.jpg: 480x640 1 bear, 131.1ms
# Speed: 3.4ms preprocess, 131.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda2.jpg: 640x640 (no detections), 146.5ms
# Speed: 7.6ms preprocess, 146.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda3.jpg: 480x640 (no detections), 101.1ms
# Speed: 2.7ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\quokka.jpg: 640x384 1 bear, 100.2ms
# Speed: 2.4ms preprocess, 100.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\tiger.jpg: 640x544 1 cat, 146.9ms
# Speed: 4.6ms preprocess, 146.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\tiger2.jpg: 608x640 (no detections), 156.9ms
# Speed: 6.5ms preprocess, 156.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\wolf.jpg: 640x608 1 cat, 141.2ms
# Speed: 5.6ms preprocess, 141.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\wolf2.jpg: 640x512 (no detections), 114.3ms
# Speed: 4.2ms preprocess, 114.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
# Hasil deteksi disimpan ke: {image_name}
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\zebra.jpg: 448x640 1 giraffe, 102.9ms
# Speed: 2.4ms preprocess, 102.9ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Hasil deteksi disimpan ke: {image_name}
