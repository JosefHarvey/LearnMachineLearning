# %%
import os, shutil
from ultralytics import YOLO
import cv2

# %%
MODEL_PATH = "yolov8x.pt"
INPUT_FOLDER = "input_images"
OUTPUT_FOLDER = "output"

def detect_object():
    model = YOLO(MODEL_PATH)

    
    if os.path.exists(OUTPUT_FOLDER):
        shutil.rmtree(OUTPUT_FOLDER)
        os.makedirs(OUTPUT_FOLDER)

    for image_name in os.listdir(INPUT_FOLDER):
        input_path = os.path.join(INPUT_FOLDER, image_name)
        output_path = os.path.join(OUTPUT_FOLDER, image_name)

        if not input_path.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        results = model.predict(input_path, conf=0.3,imgsz=640, save = False)

        for result in results:
            annotated_image = result.plot(result)
            cv2.imwrite(output_path, annotated_image)
            print (f"Hasil deteksi disimpan ke: {image_name}")

# %%
if __name__ == "__main__":
    detect_object()
# Out:
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\bunny.jpg: 448x640 1 sheep, 1942.8ms
# Speed: 16.7ms preprocess, 1942.8ms inference, 24.8ms postprocess per image at shape (1, 3, 448, 640)
# Hasil deteksi disimpan ke: bunny.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\dog.jpg: 640x480 1 dog, 1819.2ms
# Speed: 3.9ms preprocess, 1819.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Hasil deteksi disimpan ke: dog.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\elephant.jpg: 640x576 1 elephant, 2440.4ms
# Speed: 5.8ms preprocess, 2440.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
# Hasil deteksi disimpan ke: elephant.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\film.png: 640x576 (no detections), 2439.3ms
# Speed: 6.3ms preprocess, 2439.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# Hasil deteksi disimpan ke: film.png
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\fox.jpg: 640x448 1 dog, 2034.7ms
# Speed: 3.9ms preprocess, 2034.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# Hasil deteksi disimpan ke: fox.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\lion.jpg: 640x512 1 dog, 2203.9ms
# Speed: 4.0ms preprocess, 2203.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Hasil deteksi disimpan ke: lion.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\meerkat.jpg: 640x640 1 cat, 2731.8ms
# Speed: 5.3ms preprocess, 2731.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Hasil deteksi disimpan ke: meerkat.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\orangutan.jpeg: 448x640 1 dog, 1962.8ms
# Speed: 4.0ms preprocess, 1962.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Hasil deteksi disimpan ke: orangutan.jpeg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda.jpg: 480x640 1 bear, 2283.1ms
# Speed: 3.4ms preprocess, 2283.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Hasil deteksi disimpan ke: panda.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda2.jpg: 640x640 1 cat, 2693.0ms
# Speed: 8.3ms preprocess, 2693.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Hasil deteksi disimpan ke: panda2.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\panda3.jpg: 480x640 1 dog, 2091.2ms
# Speed: 2.4ms preprocess, 2091.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Hasil deteksi disimpan ke: panda3.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\quokka.jpg: 640x384 1 bear, 1728.8ms
# Speed: 2.8ms preprocess, 1728.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Hasil deteksi disimpan ke: quokka.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\tiger.jpg: 640x544 1 cat, 2390.2ms
# Speed: 5.3ms preprocess, 2390.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 544)
# Hasil deteksi disimpan ke: tiger.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\tiger2.jpg: 608x640 1 dog, 2559.7ms
# Speed: 6.9ms preprocess, 2559.7ms inference, 1.8ms postprocess per image at shape (1, 3, 608, 640)
# Hasil deteksi disimpan ke: tiger2.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\wolf.jpg: 640x608 1 cat, 2694.7ms
# Speed: 5.5ms preprocess, 2694.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 608)
# Hasil deteksi disimpan ke: wolf.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\wolf2.jpg: 640x512 1 dog, 2348.4ms
# Speed: 4.6ms preprocess, 2348.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Hasil deteksi disimpan ke: wolf2.jpg
#
# image 1/1 C:\CODE\MACHINE LEARNING\LearnMachineLearning\input_images\zebra.jpg: 448x640 1 zebra, 2011.7ms
# Speed: 5.7ms preprocess, 2011.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Hasil deteksi disimpan ke: zebra.jpg
